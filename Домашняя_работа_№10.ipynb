# %% [markdown]
# <a href="https://colab.research.google.com/github/AndreiVostriakov/Homework/blob/main/%D0%94%D0%BE%D0%BC%D0%B0%D1%88%D0%BD%D1%8F%D1%8F_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_%E2%84%9610.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import random
lst = ['robot'] * 10
lst += ['human'] * 10
random.shuffle(lst)
data = pd.DataFrame({'whoAmI':lst})
data.head()
# Out:
#   whoAmI
# 0  human
# 1  robot
# 2  human
# 3  robot
# 4  human

# %% [markdown]
# Условие задачи:
# В ячейке ниже представлен код генерирующий DataFrame, которая состоит всего из 1 столбца. Ваша задача перевести его в one hot вид. Сможете ли вы это сделать без get_dummies?

# %% [markdown]
# Решение домашней задачи

# %%
str_1 = 'robot'
new_data = pd.get_dummies(data, columns=['whoAmI'], drop_first=True)
new_data.head()
# Out:
#    whoAmI_robot
# 0             0
# 1             1
# 2             0
# 3             1
# 4             0
